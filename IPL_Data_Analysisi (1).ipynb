# %%
import pandas as pd

# %%
import numpy as np

# %%
matches = pd.read_csv("C:/Users/ab31s/Downloads/IPL_Matches 2008-2023.csv")

# %%
matches.shape
# Out:
# (1024, 19)

# %%
ball_by_ball = pd.read_csv("C:/Users/ab31s/Downloads/IPL_Ball_by_Ball 2008-23.csv")

# %%
ball_by_ball.shape
# Out:
# (243817, 16)

# %%
ball_by_ball
# Out:
#              ID  Innings  Overs  BallNumber         Batter    Bowler  \
# 0       1082591        1      0           1      DA Warner  TS Mills
# 1       1082591        1      0           2      DA Warner  TS Mills
# 2       1082591        1      0           3      DA Warner  TS Mills
# 3       1082591        1      0           4      DA Warner  TS Mills
# 4       1082591        1      0           5      DA Warner  TS Mills
# ...         ...      ...    ...         ...            ...       ...
# 243812   981019        2     19           2    Sachin Baby   B Kumar
# 243813   981019        2     19           3    Sachin Baby   B Kumar
# 243814   981019        2     19           4  Iqbal Abdulla   B Kumar
# 243815   981019        2     19           5    Sachin Baby   B Kumar
# 243816   981019        2     19           6  Iqbal Abdulla   B Kumar
#
#            NonStriker ExtraType  BatsmanRun  ExtrasRun  TotalRun  \
# 0            S Dhawan       NaN           0          0         0
# ...

# %%
ball_by_ball.shape
# Out:
# (243817, 16)

# %%
ball_by_ball.columns
# Out:
# Index(['ID', 'Innings', 'Overs', 'BallNumber', 'Batter', 'Bowler',
#        'NonStriker', 'ExtraType', 'BatsmanRun', 'ExtrasRun', 'TotalRun',
#        'IsWicketDelivery', 'PlayerOut', 'Kind', 'FieldersInvolved',
#        'BattingTeam'],
#       dtype='object')

# %%
ball_by_ball.value_counts("BallNumber")
# Out:
# BallNumber
# 1     39472
# 2     39377
# 3     39278
# 4     39176
# 5     39047
# 6     38923
# 7      7153
# 8      1173
# 9       192
# 10       24
# 11        2
# dtype: int64

# %%
ball_by_ball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243817 entries, 0 to 243816
# Data columns (total 16 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   ID                243817 non-null  int64
#  1   Innings           243817 non-null  int64
#  2   Overs             243817 non-null  int64
#  3   BallNumber        243817 non-null  int64
#  4   Batter            243817 non-null  object
#  5   Bowler            243817 non-null  object
#  6   NonStriker        243817 non-null  object
#  7   ExtraType         13059 non-null   object
#  8   BatsmanRun        243817 non-null  int64
#  9   ExtrasRun         243817 non-null  int64
#  10  TotalRun          243817 non-null  int64
#  11  IsWicketDelivery  243817 non-null  int64
#  12  PlayerOut         12067 non-null   object
#  13  Kind              12067 non-null   object
#  14  FieldersInvolved  8663 non-null    object
#  15  BattingTeam       243817 non-null  object
# ...

# %%
ball_by_ball.isna().sum()
# Out:
# ID                       0
# Innings                  0
# Overs                    0
# BallNumber               0
# Batter                   0
# Bowler                   0
# NonStriker               0
# ExtraType           230758
# BatsmanRun               0
# ExtrasRun                0
# TotalRun                 0
# IsWicketDelivery         0
# PlayerOut           231750
# Kind                231750
# FieldersInvolved    235154
# BattingTeam              0
# dtype: int64

# %%
matches
# Out:
#            ID       City        Date Season        MatchNumber  \
# 0     1082591  Hyderabad  2017-04-05   2017                  1
# 1     1082592       Pune  2017-04-06   2017                  2
# 2     1082593     Rajkot  2017-04-07   2017                  3
# 3     1082594     Indore  2017-04-08   2017                  4
# 4     1082595  Bengaluru  2017-04-08   2017                  5
# ...       ...        ...         ...    ...                ...
# 1019   981011     Raipur  2016-05-22   2016                 56
# 1020   981013  Bangalore  2016-05-24   2016        Qualifier 1
# 1021   981015      Delhi  2016-05-25   2016  Elimination Final
# 1022   981017      Delhi  2016-05-27   2016        Qualifier 2
# 1023   981019  Bangalore  2016-05-29   2016              Final
#
#                             Team1                        Team2  \
# 0             Sunrisers Hyderabad  Royal Challengers Bangalore
# 1          Rising Pune Supergiant               Mumbai Indians
# ...

# %%
ball_by_ball.head(5)
# Out:
#         ID  Innings  Overs  BallNumber     Batter    Bowler NonStriker  \
# 0  1082591        1      0           1  DA Warner  TS Mills   S Dhawan
# 1  1082591        1      0           2  DA Warner  TS Mills   S Dhawan
# 2  1082591        1      0           3  DA Warner  TS Mills   S Dhawan
# 3  1082591        1      0           4  DA Warner  TS Mills   S Dhawan
# 4  1082591        1      0           5  DA Warner  TS Mills   S Dhawan
#
#   ExtraType  BatsmanRun  ExtrasRun  TotalRun  IsWicketDelivery PlayerOut Kind  \
# 0       NaN           0          0         0                 0       NaN  NaN
# 1       NaN           0          0         0                 0       NaN  NaN
# 2       NaN           4          0         4                 0       NaN  NaN
# 3       NaN           0          0         0                 0       NaN  NaN
# 4     wides           0          2         2                 0       NaN  NaN
#
#   FieldersInvolved          BattingTeam
# ...

# %% [markdown]
# # Orange Cap Holder of each season

# %%
matches["Year"] = matches["Date"].str.split("-").str[0]

# %%
matches
# Out:
#            ID       City        Date Season        MatchNumber  \
# 0     1082591  Hyderabad  2017-04-05   2017                  1
# 1     1082592       Pune  2017-04-06   2017                  2
# 2     1082593     Rajkot  2017-04-07   2017                  3
# 3     1082594     Indore  2017-04-08   2017                  4
# 4     1082595  Bengaluru  2017-04-08   2017                  5
# ...       ...        ...         ...    ...                ...
# 1019   981011     Raipur  2016-05-22   2016                 56
# 1020   981013  Bangalore  2016-05-24   2016        Qualifier 1
# 1021   981015      Delhi  2016-05-25   2016  Elimination Final
# 1022   981017      Delhi  2016-05-27   2016        Qualifier 2
# 1023   981019  Bangalore  2016-05-29   2016              Final
#
#                             Team1                        Team2  \
# 0             Sunrisers Hyderabad  Royal Challengers Bangalore
# 1          Rising Pune Supergiant               Mumbai Indians
# ...

# %%
ball_by_ball
# Out:
#              ID  Innings  Overs  BallNumber         Batter    Bowler  \
# 0       1082591        1      0           1      DA Warner  TS Mills
# 1       1082591        1      0           2      DA Warner  TS Mills
# 2       1082591        1      0           3      DA Warner  TS Mills
# 3       1082591        1      0           4      DA Warner  TS Mills
# 4       1082591        1      0           5      DA Warner  TS Mills
# ...         ...      ...    ...         ...            ...       ...
# 243812   981019        2     19           2    Sachin Baby   B Kumar
# 243813   981019        2     19           3    Sachin Baby   B Kumar
# 243814   981019        2     19           4  Iqbal Abdulla   B Kumar
# 243815   981019        2     19           5    Sachin Baby   B Kumar
# 243816   981019        2     19           6  Iqbal Abdulla   B Kumar
#
#            NonStriker ExtraType  BatsmanRun  ExtrasRun  TotalRun  \
# 0            S Dhawan       NaN           0          0         0
# ...

# %% [markdown]
# # Merging

# %%
finaldf=ball_by_ball.merge(matches,left_on="ID",right_on = "ID")

# %%
finaldf
# Out:
#              ID  Innings  Overs  BallNumber         Batter    Bowler  \
# 0       1082591        1      0           1      DA Warner  TS Mills
# 1       1082591        1      0           2      DA Warner  TS Mills
# 2       1082591        1      0           3      DA Warner  TS Mills
# 3       1082591        1      0           4      DA Warner  TS Mills
# 4       1082591        1      0           5      DA Warner  TS Mills
# ...         ...      ...    ...         ...            ...       ...
# 243812   981019        2     19           2    Sachin Baby   B Kumar
# 243813   981019        2     19           3    Sachin Baby   B Kumar
# 243814   981019        2     19           4  Iqbal Abdulla   B Kumar
# 243815   981019        2     19           5    Sachin Baby   B Kumar
# 243816   981019        2     19           6  Iqbal Abdulla   B Kumar
#
#            NonStriker ExtraType  BatsmanRun  ExtrasRun  ...  \
# 0            S Dhawan       NaN           0          0  ...
# ...

# %%
print(matches.shape)
print(ball_by_ball.shape)
print(finaldf.shape)
# Out:
# (1024, 20)
# (243817, 16)
# (243817, 35)

# %%
finaldf.groupby("Batter")["BatsmanRun"].sum().sort_values(ascending = False)
# Out:
# Batter
# V Kohli           7273
# S Dhawan          6617
# DA Warner         6399
# RG Sharma         6213
# SK Raina          5536
#                   ...
# L Ablish             0
# S Kaushik            0
# U Kaul               0
# V Pratap Singh       0
# S Lamichhane         0
# Name: BatsmanRun, Length: 637, dtype: int64

# %%
finaldf.groupby(["Year","Batter"])["BatsmanRun"].sum().sort_values(ascending= False)
# Out:
# Year  Batter
# 2016  V Kohli             973
# 2023  Shubman Gill        890
# 2022  JC Buttler          863
# 2016  DA Warner           848
# 2018  KS Williamson       735
#                          ...
# 2008  S Sreesanth           0
# 2010  AG Paunikar           0
# 2023  KM Asif               0
# 2019  Mujeeb Ur Rahman      0
# 2012  A Chandila            0
# Name: BatsmanRun, Length: 2446, dtype: int64

# %%
finaldf.groupby(["Year","Batter"])["BatsmanRun"].sum().sort_values(ascending=False).reset_index()
# Out:
#       Year            Batter  BatsmanRun
# 0     2016           V Kohli         973
# 1     2023      Shubman Gill         890
# 2     2022        JC Buttler         863
# 3     2016         DA Warner         848
# 4     2018     KS Williamson         735
# ...    ...               ...         ...
# 2441  2008       S Sreesanth           0
# 2442  2010       AG Paunikar           0
# 2443  2023           KM Asif           0
# 2444  2019  Mujeeb Ur Rahman           0
# 2445  2012        A Chandila           0
#
# [2446 rows x 3 columns]

# %%
orange_cap_holders=finaldf.groupby(["Year","Batter"])["BatsmanRun"].sum().sort_values(ascending=False).reset_index().drop_duplicates(subset = "Year",keep="first")

# %%
orange_cap_holders
# Out:
#     Year         Batter  BatsmanRun
# 0   2016        V Kohli         973
# 1   2023   Shubman Gill         890
# 2   2022     JC Buttler         863
# 4   2018  KS Williamson         735
# 5   2012       CH Gayle         733
# 6   2013     MEK Hussey         733
# 9   2019      DA Warner         692
# 12  2020       KL Rahul         676
# 14  2014     RV Uthappa         660
# 16  2017      DA Warner         641
# 19  2021     RD Gaikwad         635
# 23  2010   SR Tendulkar         618
# 25  2008       SE Marsh         616
# 27  2011       CH Gayle         608
# 34  2009      ML Hayden         572
# 38  2015      DA Warner         562

# %%
orange_cap_holders.sort_values("Year")
# Out:
#     Year         Batter  BatsmanRun
# 25  2008       SE Marsh         616
# 34  2009      ML Hayden         572
# 23  2010   SR Tendulkar         618
# 27  2011       CH Gayle         608
# 5   2012       CH Gayle         733
# 6   2013     MEK Hussey         733
# 14  2014     RV Uthappa         660
# 38  2015      DA Warner         562
# 0   2016        V Kohli         973
# 16  2017      DA Warner         641
# 4   2018  KS Williamson         735
# 9   2019      DA Warner         692
# 12  2020       KL Rahul         676
# 19  2021     RD Gaikwad         635
# 2   2022     JC Buttler         863
# 1   2023   Shubman Gill         890

# %% [markdown]
# # Individual_Runs_highest

# %%
Individual_Runs_highest = finaldf.groupby(["ID","Batter"])["BatsmanRun"].sum().sort_values(ascending=False).reset_index()

# %%
Individual_Runs_highest.head(10)
# Out:
#         ID          Batter  BatsmanRun
# 0   598027        CH Gayle         175
# 1   335982     BB McCullum         158
# 2  1304112       Q de Kock         140
# 3   829795  AB de Villiers         133
# 4  1216510        KL Rahul         132
# 5  1370352    Shubman Gill         129
# 6   980987  AB de Villiers         129
# 7  1136602         RR Pant         128
# 8   548372        CH Gayle         128
# 9   419137         M Vijay         127

# %%
ball_by_ball
# Out:
#              ID  Innings  Overs  BallNumber         Batter    Bowler  \
# 0       1082591        1      0           1      DA Warner  TS Mills
# 1       1082591        1      0           2      DA Warner  TS Mills
# 2       1082591        1      0           3      DA Warner  TS Mills
# 3       1082591        1      0           4      DA Warner  TS Mills
# 4       1082591        1      0           5      DA Warner  TS Mills
# ...         ...      ...    ...         ...            ...       ...
# 243812   981019        2     19           2    Sachin Baby   B Kumar
# 243813   981019        2     19           3    Sachin Baby   B Kumar
# 243814   981019        2     19           4  Iqbal Abdulla   B Kumar
# 243815   981019        2     19           5    Sachin Baby   B Kumar
# 243816   981019        2     19           6  Iqbal Abdulla   B Kumar
#
#            NonStriker ExtraType  BatsmanRun  ExtrasRun  TotalRun  \
# 0            S Dhawan       NaN           0          0         0
# ...

# %%
newdf=finaldf[ball_by_ball["Kind"]!='run out']

# %%
newdf.head(50)
# Out:
#          ID  Innings  Overs  BallNumber        Batter       Bowler  \
# 0   1082591        1      0           1     DA Warner     TS Mills
# 1   1082591        1      0           2     DA Warner     TS Mills
# 2   1082591        1      0           3     DA Warner     TS Mills
# 3   1082591        1      0           4     DA Warner     TS Mills
# 4   1082591        1      0           5     DA Warner     TS Mills
# 5   1082591        1      0           6      S Dhawan     TS Mills
# 6   1082591        1      0           7      S Dhawan     TS Mills
# 7   1082591        1      1           1      S Dhawan  A Choudhary
# 8   1082591        1      1           2     DA Warner  A Choudhary
# 9   1082591        1      1           3     DA Warner  A Choudhary
# 10  1082591        1      1           4     DA Warner  A Choudhary
# 11  1082591        1      1           5     DA Warner  A Choudhary
# 12  1082591        1      1           6  MC Henriques  A Choudhary
# ...

# %%
pirple_cap_holders=newdf.groupby(["Year","Bowler"])["IsWicketDelivery"].sum().sort_values(ascending=False).reset_index().drop_duplicates(subset="Year",keep="first")

# %%
pirple_cap_holders
# Out:
#     Year          Bowler  IsWicketDelivery
# 0   2021        HV Patel                32
# 1   2020        K Rabada                32
# 2   2013        DJ Bravo                32
# 5   2023  Mohammed Shami                28
# 6   2011      SL Malinga                28
# 7   2022       YS Chahal                27
# 10  2015        DJ Bravo                26
# 11  2019     Imran Tahir                26
# 14  2017         B Kumar                26
# 15  2012        M Morkel                25
# 20  2018          AJ Tye                24
# 24  2014       MM Sharma                23
# 25  2009        RP Singh                23
# 29  2016         B Kumar                23
# 35  2008   Sohail Tanvir                22
# 40  2010         PP Ojha                21

# %%
pirple_cap_holders.sort_values("Year")
# Out:
#     Year          Bowler  IsWicketDelivery
# 35  2008   Sohail Tanvir                22
# 25  2009        RP Singh                23
# 40  2010         PP Ojha                21
# 6   2011      SL Malinga                28
# 15  2012        M Morkel                25
# 2   2013        DJ Bravo                32
# 24  2014       MM Sharma                23
# 10  2015        DJ Bravo                26
# 29  2016         B Kumar                23
# 14  2017         B Kumar                26
# 20  2018          AJ Tye                24
# 11  2019     Imran Tahir                26
# 1   2020        K Rabada                32
# 0   2021        HV Patel                32
# 7   2022       YS Chahal                27
# 5   2023  Mohammed Shami                28

# %%
ball_by_ball
# Out:
#              ID  Innings  Overs  BallNumber         Batter    Bowler  \
# 0       1082591        1      0           1      DA Warner  TS Mills
# 1       1082591        1      0           2      DA Warner  TS Mills
# 2       1082591        1      0           3      DA Warner  TS Mills
# 3       1082591        1      0           4      DA Warner  TS Mills
# 4       1082591        1      0           5      DA Warner  TS Mills
# ...         ...      ...    ...         ...            ...       ...
# 243812   981019        2     19           2    Sachin Baby   B Kumar
# 243813   981019        2     19           3    Sachin Baby   B Kumar
# 243814   981019        2     19           4  Iqbal Abdulla   B Kumar
# 243815   981019        2     19           5    Sachin Baby   B Kumar
# 243816   981019        2     19           6  Iqbal Abdulla   B Kumar
#
#            NonStriker ExtraType  BatsmanRun  ExtrasRun  TotalRun  \
# 0            S Dhawan       NaN           0          0         0
# ...

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
# Create a bar plot
plt.figure(figsize=(12, 6))
plt.bar(orange_cap_holders['Year'], orange_cap_holders['BatsmanRun'], color='Red')
plt.xlabel('Year')
plt.ylabel('Total Runs')
plt.title('Orange Cap Holders Runs')
plt.xticks(orange_cap_holders['Year'])
plt.xticks(rotation=45)
plt.tight_layout()


plt.show()

# %% [markdown]
# # No of Sixes

# %%
filter_mask = finaldf["BatsmanRun"]==6

# %%
sixes=finaldf[filter_mask]

# %%
sixes
# Out:
#              ID  Innings  Overs  BallNumber        Batter             Bowler  \
# 10      1082591        1      1           4     DA Warner        A Choudhary
# 47      1082591        1      7           4  MC Henriques            TM Head
# 75      1082591        1     12           2  Yuvraj Singh        A Choudhary
# 89      1082591        1     14           3  Yuvraj Singh          S Aravind
# 91      1082591        1     14           5  MC Henriques          S Aravind
# ...         ...      ...    ...         ...           ...                ...
# 243752   981019        2      9           2       V Kohli  Mustafizur Rahman
# 243770   981019        2     12           2       V Kohli            BB Sran
# 243785   981019        2     14           5     SR Watson       MC Henriques
# 243797   981019        2     16           5     STR Binny  Mustafizur Rahman
# 243810   981019        2     18           6   Sachin Baby  Mustafizur Rahman
#
# ...

# %%
sixes.groupby("BattingTeam")["BatsmanRun"]

# %%
no_of_sixes=sixes.groupby(["Year","BattingTeam"])["BatsmanRun"].value_counts().sort_values(ascending=False)

# %%
no_of_sixes
# Out:
# Year  BattingTeam                  BatsmanRun
# 2018  Chennai Super Kings          6             145
# 2019  Kolkata Knight Riders        6             143
# 2016  Royal Challengers Bangalore  6             142
# 2023  Mumbai Indians               6             140
# 2020  Mumbai Indians               6             137
#                                                 ...
# 2009  Delhi Daredevils             6              51
# 2011  Deccan Chargers              6              48
# 2009  Rajasthan Royals             6              47
# 2011  Kolkata Knight Riders        6              45
#       Rajasthan Royals             6              42
# Name: BatsmanRun, Length: 136, dtype: int64

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns

# %%
finaldf
# Out:
#              ID  Innings  Overs  BallNumber         Batter    Bowler  \
# 0       1082591        1      0           1      DA Warner  TS Mills
# 1       1082591        1      0           2      DA Warner  TS Mills
# 2       1082591        1      0           3      DA Warner  TS Mills
# 3       1082591        1      0           4      DA Warner  TS Mills
# 4       1082591        1      0           5      DA Warner  TS Mills
# ...         ...      ...    ...         ...            ...       ...
# 243812   981019        2     19           2    Sachin Baby   B Kumar
# 243813   981019        2     19           3    Sachin Baby   B Kumar
# 243814   981019        2     19           4  Iqbal Abdulla   B Kumar
# 243815   981019        2     19           5    Sachin Baby   B Kumar
# 243816   981019        2     19           6  Iqbal Abdulla   B Kumar
#
#            NonStriker ExtraType  BatsmanRun  ExtrasRun  ...  \
# 0            S Dhawan       NaN           0          0  ...
# ...

# %%
finaldf["Kind"].value_counts()
# Out:
# caught                   7437
# bowled                   2089
# run out                  1062
# lbw                       750
# caught and bowled         349
# stumped                   345
# retired hurt               15
# hit wicket                 15
# retired out                 3
# obstructing the field       2
# Name: Kind, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.countplot(data=finaldf, x="Kind")
# Out:
# <AxesSubplot:xlabel='Kind', ylabel='count'>

# %%
finaldf["TossDecision"].value_counts().plot(kind= "pie", autopct='%2f')
# Out:
# <AxesSubplot:ylabel='TossDecision'>

# %%
finaldf["Kind"].value_counts().plot(kind="pie",autopct= '%.2f')
# Out:
# <AxesSubplot:ylabel='Kind'>

# %%
akku=matches["MatchNumber"]=="Final"

# %%
df=matches[akku]

# %%
df
# Out:
#            ID          City        Date   Season MatchNumber  \
# 58    1082650     Hyderabad  2017-05-21     2017       Final
# 118   1136620        Mumbai  2018-05-27     2018       Final
# 178   1181768     Hyderabad  2019-05-12     2019       Final
# 238   1237181           NaN  2020-11-10  2020/21       Final
# 298   1254117         Dubai  2021-10-15     2021       Final
# 372   1312200     Ahmedabad  2022-05-29     2022       Final
# 446   1370353     Ahmedabad  2023-05-29     2023       Final
# 504    336040        Mumbai  2008-06-01  2007/08       Final
# 561    392239  Johannesburg  2009-05-24     2009       Final
# 621    419165        Mumbai  2010-04-25  2009/10       Final
# 694    501271       Chennai  2011-05-28     2011       Final
# 768    548381       Chennai  2012-05-27     2012       Final
# 844    598073       Kolkata  2013-05-26     2013       Final
# 904    734049     Bangalore  2014-06-01     2014       Final
# ...

# %%
mymatch=finaldf[finaldf["ID"]==1181768]

# %%
mymatch
# Out:
#             ID  Innings  Overs  BallNumber     Batter      Bowler NonStriker  \
# 42213  1181768        1      0           1  Q de Kock   DL Chahar  RG Sharma
# 42214  1181768        1      0           2  RG Sharma   DL Chahar  Q de Kock
# 42215  1181768        1      0           3  Q de Kock   DL Chahar  RG Sharma
# 42216  1181768        1      0           4  Q de Kock   DL Chahar  RG Sharma
# 42217  1181768        1      0           5  Q de Kock   DL Chahar  RG Sharma
# ...        ...      ...    ...         ...        ...         ...        ...
# 42455  1181768        2     19           2  RA Jadeja  SL Malinga  SR Watson
# 42456  1181768        2     19           3  SR Watson  SL Malinga  RA Jadeja
# 42457  1181768        2     19           4  SR Watson  SL Malinga  RA Jadeja
# 42458  1181768        2     19           5  SN Thakur  SL Malinga  RA Jadeja
# 42459  1181768        2     19           6  SN Thakur  SL Malinga  RA Jadeja
#
# ...

# %%
bins = list(range(0,max(mymatch["Overs"]) +6,5))
mymatch['Over_Interval']=pd.cut(mymatch["Overs"], bins=bins, labels=[f"{i}-{i+4}" for i in bins[:-1]])
# Out:
# C:\Users\ab31s\AppData\Local\Temp\ipykernel_15080\3601864693.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mymatch['Over_Interval']=pd.cut(mymatch["Overs"], bins=bins, labels=[f"{i}-{i+4}" for i in bins[:-1]])

# %%
mymatch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 247 entries, 42213 to 42459
# Data columns (total 36 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                247 non-null    int64
#  1   Innings           247 non-null    int64
#  2   Overs             247 non-null    int64
#  3   BallNumber        247 non-null    int64
#  4   Batter            247 non-null    object
#  5   Bowler            247 non-null    object
#  6   NonStriker        247 non-null    object
#  7   ExtraType         9 non-null      object
#  8   BatsmanRun        247 non-null    int64
#  9   ExtrasRun         247 non-null    int64
#  10  TotalRun          247 non-null    int64
#  11  IsWicketDelivery  247 non-null    int64
#  12  PlayerOut         15 non-null     object
#  13  Kind              15 non-null     object
#  14  FieldersInvolved  7 non-null      object
#  15  BattingTeam       247 non-null    object
# ...

# %%
mymatch.tail(50)
# Out:
#             ID  Innings  Overs  BallNumber     Batter          Bowler  \
# 42410  1181768        2     11           6  SR Watson       RD Chahar
# 42411  1181768        2     12           1   MS Dhoni       HH Pandya
# 42412  1181768        2     12           2  SR Watson       HH Pandya
# 42413  1181768        2     12           3  SR Watson       HH Pandya
# 42414  1181768        2     12           4  SR Watson       HH Pandya
# 42415  1181768        2     12           5  SR Watson       HH Pandya
# 42416  1181768        2     12           6  SR Watson       HH Pandya
# 42417  1181768        2     12           7  SR Watson       HH Pandya
# 42418  1181768        2     13           1   DJ Bravo       RD Chahar
# 42419  1181768        2     13           2   DJ Bravo       RD Chahar
# 42420  1181768        2     13           3  SR Watson       RD Chahar
# 42421  1181768        2     13           4   DJ Bravo       RD Chahar
# ...

# %%
mymatch.columns
# Out:
# Index(['ID', 'Innings', 'Overs', 'BallNumber', 'Batter', 'Bowler',
#        'NonStriker', 'ExtraType', 'BatsmanRun', 'ExtrasRun', 'TotalRun',
#        'IsWicketDelivery', 'PlayerOut', 'Kind', 'FieldersInvolved',
#        'BattingTeam', 'City', 'Date', 'Season', 'MatchNumber', 'Team1',
#        'Team2', 'Venue', 'TossWinner', 'TossDecision', 'WinningTeam', 'Margin',
#        'WonBy', 'Player_of_Match', 'Team1Players', 'Team2Players', 'Umpire1',
#        'Umpire2', 'Umpire3', 'Year', 'Over_Interval'],
#       dtype='object')

# %%
v1 = mymatch.groupby(["BattingTeam","Overs"])["TotalRun"].sum()

# %%
v1
# Out:
# BattingTeam          Overs
# Chennai Super Kings  0         7
#                      1         5
#                      2         7
#                      3        14
#                      4         5
#                      5        15
#                      6         4
#                      7         3
#                      8        10
#                      9         2
#                      10        1
#                      11        6
#                      12        3
#                      13        3
#                      14        3
#                      15       20
#                      16        4
#                      17       20
#                      18        9
#                      19        7
# Mumbai Indians       0         2
#                      1         8
#                      2        20
#                      3         7
#                      4         8
#                      5         0
#                      6         5
# ...

# %%
v2=v1[v1["IsWicketDelivery"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'IsWicketDelivery'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
plt.figure(figsize=(10,6))
sns.barplot(x = mymatch["Overs"],y= mymatch["TotalRun"],hue = mymatch["BattingTeam"])
# Out:
# <AxesSubplot:xlabel='Overs', ylabel='TotalRun'>

# %%
ball_by_ball
# Out:
#              ID  Innings  Overs  BallNumber         Batter    Bowler  \
# 0       1082591        1      0           1      DA Warner  TS Mills
# 1       1082591        1      0           2      DA Warner  TS Mills
# 2       1082591        1      0           3      DA Warner  TS Mills
# 3       1082591        1      0           4      DA Warner  TS Mills
# 4       1082591        1      0           5      DA Warner  TS Mills
# ...         ...      ...    ...         ...            ...       ...
# 243812   981019        2     19           2    Sachin Baby   B Kumar
# 243813   981019        2     19           3    Sachin Baby   B Kumar
# 243814   981019        2     19           4  Iqbal Abdulla   B Kumar
# 243815   981019        2     19           5    Sachin Baby   B Kumar
# 243816   981019        2     19           6  Iqbal Abdulla   B Kumar
#
#            NonStriker ExtraType  BatsmanRun  ExtrasRun  TotalRun  \
# 0            S Dhawan       NaN           0          0         0
# ...
